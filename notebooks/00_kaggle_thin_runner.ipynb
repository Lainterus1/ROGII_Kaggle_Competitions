# %% [markdown]
# # ROGII Baseline - Kaggle Run
#
# Thin runner: clone repo, install deps, train LightGBM, generate submission.
#
# Repo: https://github.com/Lainterus1/ROGII_Kaggle_Competitions

# %%
# !git clone https://github.com/Lainterus1/ROGII_Kaggle_Competitions.git

# %%
# %cd ROGII_Kaggle_Competitions
# !pip install -r requirements.txt

# %%
# !python scripts/run_train.py \
  --data-dir /kaggle/input/rogii-wellbore-geology-prediction \
  --include-tvt-input \
  --output-model /kaggle/working/models/baseline_lgbm.pkl

# %%
# !python scripts/run_predict.py \
  --data-dir /kaggle/input/rogii-wellbore-geology-prediction \
  --model /kaggle/working/models/baseline_lgbm.pkl \
  --include-tvt-input \
  --output /kaggle/working/submission.csv
