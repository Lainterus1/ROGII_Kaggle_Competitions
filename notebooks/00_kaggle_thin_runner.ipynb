# %% [markdown]
# # ROGII Baseline - Kaggle Run (offline)
#
# Internet OFF. Uses `rogii-repo` Kaggle Dataset instead of git clone.
# LightGBM, scikit-learn, pandas are pre-installed in Kaggle environment.
#
# Dataset: `/kaggle/input/datasets/<user>/rogii-repo/ROGII_Kaggle_Competitions-main`

# %%
# !cp -r /kaggle/input/datasets/daniilgonchar/rogii-repo/ROGII_Kaggle_Competitions-main/* /kaggle/working/

# %%
# %cd /kaggle/working

# %%
# !python scripts/run_train.py \
  --data-dir /kaggle/input/competitions/rogii-wellbore-geology-prediction \
  --include-tvt-input \
  --output-model /kaggle/working/models/baseline_lgbm.pkl

# %%
# !python scripts/run_predict.py \
  --data-dir /kaggle/input/competitions/rogii-wellbore-geology-prediction \
  --model /kaggle/working/models/baseline_lgbm.pkl \
  --include-tvt-input \
  --output /kaggle/working/submission.csv
