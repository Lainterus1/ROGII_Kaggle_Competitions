# %% [markdown]
# # ROGII — Update Kaggle Repo Dataset (Internet ON)
#
# Clones latest code from GitHub, then you create/update the `rogii-repo` Kaggle Dataset.
#
# **Setup (once):** File → Link to GitHub → `Lainterus1/ROGII_Kaggle_Competitions` → path: `notebooks/02_kaggle_update_repo.ipynb`
# **Before each run:** File → Pull from GitHub (to get latest notebook code)
#
# **Run this after every `git push` to GitHub.**
#
# This notebook only updates the code. It does NOT train or predict.
#
# After this notebook finishes:
# 1. Click Save Version → Create Dataset → name it `rogii-repo` (private)
# 2. If model/features changed → run `01_kaggle_train.ipynb` → create/update `rogii-models`
# 3. For submission → run `00_kaggle_inference.ipynb` (internet OFF, code from `rogii-repo` Dataset)

# %%
# !git clone https://github.com/Lainterus1/ROGII_Kaggle_Competitions.git

# %% [markdown]
# ## Done
#
# Now create the Kaggle Dataset:
#
# 1. Click **Save Version** (top right)
# 2. In the output section, click **Create Dataset**
# 3. Name it **`rogii-repo`**, make it **Private**
# 4. Attach `rogii-repo` to `00_kaggle_inference.ipynb` as input
#
# **Next step:**
# - Model/features changed → open `01_kaggle_train` → Pull from GitHub → Run
# - Only need submission → open `00_kaggle_inference` → Run (internet OFF)
