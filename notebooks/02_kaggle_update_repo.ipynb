# %% [markdown]
# # ROGII — Update Kaggle Repo Dataset (Internet ON)
#
# Clones latest code from GitHub, then create/update the `rogii-repo` Kaggle Dataset.
#
# **Every push to GitHub:** open → Run → Save → rogii-repo

# %%
# !git clone https://github.com/Lainterus1/ROGII_Kaggle_Competitions.git

# %% [markdown]
# ## Done
#
# Create the Kaggle Dataset:
# 1. Save Version (top right)
# 2. Create Dataset → name `rogii-repo` (private)
