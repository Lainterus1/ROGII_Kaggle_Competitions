# %% [markdown]
# # ROGII - Update Kaggle Repo Dataset (Internet ON)
#
# Clones latest code from GitHub, then create/update the `rogii-repo-v2` Kaggle Dataset from the notebook output.

# %%
# !git clone https://github.com/Lainterus1/ROGII_Kaggle_Competitions.git
# !find ROGII_Kaggle_Competitions -maxdepth 2 -type f | head -30

# %% [markdown]
# ## Done
#
# Create/update the Kaggle Dataset `rogii-repo-v2` from the notebook output. The offline inference notebook auto-detects either this nested layout or a flat dataset layout.
